# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/housing prices.csv")

print("Dataset Loaded Successfully")

# Select important columns for demonstration
housing_df = df[
    [
        "longitude",
        "latitude",
        "median_income",
        "total_rooms",
        "median_house_value",
        "ocean_proximity"
    ]
].head(5)

print("\nOriginal DataFrame:")
display(housing_df)

print("\n1. First 5 rows:")
display(housing_df.head())

print("\n2. Last 2 rows:")
display(housing_df.tail(2))

print("\n3. Shape:")
print(housing_df.shape)

print("\n4. Column Names:")
print(housing_df.columns)

print("\n5. DataFrame Information:")
housing_df.info()

print("\n6. Statistical Summary:")
display(housing_df.describe())

print("\n7. Missing Values:")
print(df.isnull().sum())

print("\n8. Non-Missing Values:")
print(df.notnull().sum())

# Remove blank rows and duplicates
df = df.dropna()
df = df.drop_duplicates()

print("\n9. Cleaned Dataset:")
display(df.head())

print("\n10. Records with Median House Value greater than 300000:")
display(
    df[df["median_house_value"] > 300000][
        [
            "longitude",
            "latitude",
            "median_income",
            "total_rooms",
            "median_house_value",
            "ocean_proximity"
        ]
    ].head()
)
# Out:
# Dataset Loaded Successfully
#
# Original DataFrame:
#    longitude  latitude  median_income  total_rooms  median_house_value  \
# 0    -122.23     37.88         8.3252        880.0            452600.0
# 1    -122.22     37.86         8.3014       7099.0            358500.0
# 2    -122.24     37.85         7.2574       1467.0            352100.0
# 3    -122.25     37.85         5.6431       1274.0            341300.0
# 4    -122.25     37.85         3.8462       1627.0            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
# 1. First 5 rows:
#    longitude  latitude  median_income  total_rooms  median_house_value  \
# 0    -122.23     37.88         8.3252        880.0            452600.0
# 1    -122.22     37.86         8.3014       7099.0            358500.0
# 2    -122.24     37.85         7.2574       1467.0            352100.0
# ...
